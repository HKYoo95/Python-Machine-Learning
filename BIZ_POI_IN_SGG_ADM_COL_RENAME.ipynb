# %%
import geopandas as gpd

# %%
anal_data = gpd.read_file('data/Point in Polygon_data/BIZ_POI_IN_SGG_ADM/BIZ_POI_in_SGG_ADM.shp',encoding = 'utf-8')
anal_data
# Out:
#        ADM_CODE SID_NAME SGG_NAME  COUNT          AREA  COUNT_KM2  \
# 0    1111000000    서울특별시      종로구    431    239.751272   1.797696
# 1    1114000000    서울특별시       중구    421     99.624023   4.225888
# 2    1117000000    서울특별시      용산구    214    218.976367   0.977274
# 3    1120000000    서울특별시      성동구    209    168.012399   1.243956
# 4    1121500000    서울특별시      광진구    217    170.301293   1.274212
# 5    1123000000    서울특별시     동대문구    251    142.378262   1.762910
# 6    1126000000    서울특별시      중랑구    214    185.237007   1.155277
# 7    1129000000    서울특별시      성북구    236    245.898850   0.959744
# 8    1130500000    서울특별시      강북구    176    236.181207   0.745191
# 9    1132000000    서울특별시      도봉구    182    206.740763   0.880330
# 10   1135000000    서울특별시      노원구    379    355.764864   1.065310
# 11   1138000000    서울특별시      은평구    230    297.722933   0.772530
# 12   1141000000    서울특별시     서대문구    235    176.797639   1.329203
# ...

# %%
anal_data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 7 columns):
# ADM_CODE     250 non-null object
# SID_NAME     250 non-null object
# SGG_NAME     249 non-null object
# count        250 non-null int64
# area         250 non-null float64
# count/km2    250 non-null float64
# geometry     250 non-null geometry
# dtypes: float64(2), geometry(1), int64(1), object(3)
# memory usage: 13.8+ KB

# %%
anal_data.rename(columns = {'count':'COUNT','area':'AREA','count/km2':'COUNT_KM2'},inplace=True)
anal_data
# Out:
#        ADM_CODE SID_NAME SGG_NAME  COUNT          AREA  COUNT_KM2  \
# 0    1111000000    서울특별시      종로구    431    239.751272   1.797696
# 1    1114000000    서울특별시       중구    421     99.624023   4.225888
# 2    1117000000    서울특별시      용산구    214    218.976367   0.977274
# 3    1120000000    서울특별시      성동구    209    168.012399   1.243956
# 4    1121500000    서울특별시      광진구    217    170.301293   1.274212
# 5    1123000000    서울특별시     동대문구    251    142.378262   1.762910
# 6    1126000000    서울특별시      중랑구    214    185.237007   1.155277
# 7    1129000000    서울특별시      성북구    236    245.898850   0.959744
# 8    1130500000    서울특별시      강북구    176    236.181207   0.745191
# 9    1132000000    서울특별시      도봉구    182    206.740763   0.880330
# 10   1135000000    서울특별시      노원구    379    355.764864   1.065310
# 11   1138000000    서울특별시      은평구    230    297.722933   0.772530
# 12   1141000000    서울특별시     서대문구    235    176.797639   1.329203
# ...

# %%
anal_data
# Out:
#        ADM_CODE SID_NAME SGG_NAME  COUNT          AREA  COUNT_KM2  \
# 0    1111000000    서울특별시      종로구    431    239.751272   1.797696
# 1    1114000000    서울특별시       중구    421     99.624023   4.225888
# 2    1117000000    서울특별시      용산구    214    218.976367   0.977274
# 3    1120000000    서울특별시      성동구    209    168.012399   1.243956
# 4    1121500000    서울특별시      광진구    217    170.301293   1.274212
# 5    1123000000    서울특별시     동대문구    251    142.378262   1.762910
# 6    1126000000    서울특별시      중랑구    214    185.237007   1.155277
# 7    1129000000    서울특별시      성북구    236    245.898850   0.959744
# 8    1130500000    서울특별시      강북구    176    236.181207   0.745191
# 9    1132000000    서울특별시      도봉구    182    206.740763   0.880330
# 10   1135000000    서울특별시      노원구    379    355.764864   1.065310
# 11   1138000000    서울특별시      은평구    230    297.722933   0.772530
# 12   1141000000    서울특별시     서대문구    235    176.797639   1.329203
# ...

# %%
anal_data.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
anal_data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 7 columns):
# ADM_CODE     250 non-null object
# SID_NAME     250 non-null object
# SGG_NAME     249 non-null object
# COUNT        250 non-null int64
# AREA         250 non-null float64
# COUNT_KM2    250 non-null float64
# geometry     250 non-null geometry
# dtypes: float64(2), geometry(1), int64(1), object(3)
# memory usage: 13.8+ KB

# %%
anal_data['ADM_CODE']
# Out:
# 0      1111000000
# 1      1114000000
# 2      1117000000
# 3      1120000000
# 4      1121500000
# 5      1123000000
# 6      1126000000
# 7      1129000000
# 8      1130500000
# 9      1132000000
# 10     1135000000
# 11     1138000000
# 12     1141000000
# 13     1144000000
# 14     1147000000
# 15     1150000000
# 16     1153000000
# 17     1154500000
# 18     1156000000
# 19     1159000000
# 20     1162000000
# 21     1165000000
# 22     1168000000
# 23     1171000000
# 24     1174000000
# 25     2611000000
# 26     2614000000
# 27     2617000000
# 28     2620000000
# 29     2623000000
#           ...
# 220    4784000000
# 221    4785000000
# 222    4790000000
# 223    4792000000
# 224    4793000000
# 225    4794000000
# 226    4812100000
# 227    4812300000
# 228    4812500000
# 229    4812700000
# 230    4812900000
# 231    4817000000
# 232    4822000000
# 233    4824000000
# 234    4825000000
# 235    4827000000
# 236    4831000000
# 237    4833000000
# 238    4872000000
# ...

# %%
anal_data['ADM_CODE'] = anal_data['ADM_CODE'].astype(str)
anal_data['SID_NAME'] = anal_data['SID_NAME'].astype(str)
anal_data['SGG_NAME'] = anal_data['SGG_NAME'].astype(str)

# %%
anal_data.to_file('data/Point in Polygon_data/BIZ_POI_IN_SGG_ADM/BIZ_POI_IN_SGG_ADM.shp',encoding='utf-8')

# %%
anal_data.to_file('BIZ_POI_IN_SGG_ADM.shp',encoding='utf-8')
